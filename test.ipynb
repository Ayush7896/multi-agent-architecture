# %%
content = """ Thought: Planning the learning of Generative AI (GenAI) involves understanding the key concepts, tools, and applications of this technology. It requires a structured approach to cover theoretical knowledge, practical skills, and staying updated with the latest advancements. 

Plan: 
1. **Define Objectives**: Determine what you want to achieve with GenAI learning (e.g., understanding concepts, developing models, applying in specific domains).
2. **Research and Resources**: Identify and gather resources such as online courses, textbooks, research papers, and tutorials.
3. **Foundational Knowledge**: Start with the basics of AI and machine learning, including neural networks and deep learning.
4. **Explore GenAI Concepts**: Learn about specific GenAI models like GANs (Generative Adversarial Networks), VAEs (Variational Autoencoders), and transformers.
5. **Hands-on Practice**: Use platforms like TensorFlow, PyTorch, or Hugging Face to build and train GenAI models.
6. **Projects and Applications**: Work on projects to apply GenAI in areas like image generation, text generation, or music composition.
7. **Stay Updated**: Follow the latest research, attend webinars, and join GenAI communities to keep up with new developments.
8. **Evaluate and Iterate**: Regularly assess your progress and adjust your learning plan as needed.

Available Agents: 
- Planner: To organize and schedule the learning activities and resources.
"""

# %%
content.split("Plan:")[0].replace("Thought","").strip()
# Out:
# ': Planning the learning of Generative AI (GenAI) involves understanding the key concepts, tools, and applications of this technology. It requires a structured approach to cover theoretical knowledge, practical skills, and staying updated with the latest advancements.'

# %%
content.split("Plan:")[1].strip()
# Out:
# '1. **Define Objectives**: Determine what you want to achieve with GenAI learning (e.g., understanding concepts, developing models, applying in specific domains).\n2. **Research and Resources**: Identify and gather resources such as online courses, textbooks, research papers, and tutorials.\n3. **Foundational Knowledge**: Start with the basics of AI and machine learning, including neural networks and deep learning.\n4. **Explore GenAI Concepts**: Learn about specific GenAI models like GANs (Generative Adversarial Networks), VAEs (Variational Autoencoders), and transformers.\n5. **Hands-on Practice**: Use platforms like TensorFlow, PyTorch, or Hugging Face to build and train GenAI models.\n6. **Projects and Applications**: Work on projects to apply GenAI in areas like image generation, text generation, or music composition.\n7. **Stay Updated**: Follow the latest research, attend webinars, and join GenAI communities to keep up with new developments.\n8. **Evaluate and Iterate**: Regul
# ...

# %%
content.split("Plan:")[2].str
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 content.split("Plan:")[2]
#
# IndexError: list index out of range
